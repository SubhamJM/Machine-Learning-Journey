# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/movies_dataset.csv')

# %%
dataset
# Out:
#         MovieID                         Title        Genre  ReleaseYear  \
# 0             1          Might toward capital       Comedy         2003
# 1             2         He however experience       Comedy         1988
# 2             3  Star responsibility politics       Comedy         1971
# 3             4                  Exactly live       Comedy         1998
# 4             5      Focus improve especially  Documentary         2021
# ...         ...                           ...          ...          ...
# 423109   423110           Anyone brother nice        Drama         2014
# 423110   423111                  Analysis day  Documentary         1992
# 423111   423112                  Bill surface       Action         1982
# 423112   423113            Stand main measure       Comedy         1981
# 423113   423114                      Tough he       Action         2016
#
#        ReleaseDate Country    BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423114 entries, 0 to 423113
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   MovieID               423114 non-null  int64
#  1   Title                 423114 non-null  object
#  2   Genre                 423114 non-null  object
#  3   ReleaseYear           423114 non-null  int64
#  4   ReleaseDate           423114 non-null  object
#  5   Country               423114 non-null  object
#  6   BudgetUSD             423114 non-null  float64
#  7   US_BoxOfficeUSD       423114 non-null  float64
#  8   Global_BoxOfficeUSD   423114 non-null  float64
#  9   Opening_Day_SalesUSD  423114 non-null  float64
#  10  One_Week_SalesUSD     423114 non-null  float64
#  11  IMDbRating            423114 non-null  float64
#  12  RottenTomatoesScore   423114 non-null  int64
#  13  NumVotesIMDb          423114 non-null  int64
# ...

# %%
dataset.head(3)
# Out:
#    MovieID                         Title   Genre  ReleaseYear ReleaseDate  \
# 0        1          Might toward capital  Comedy         2003  28-09-2003
# 1        2         He however experience  Comedy         1988  14-02-1988
# 2        3  Star responsibility politics  Comedy         1971  02-11-1971
#
#   Country   BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# 0   China  6577427.79       6613685.82          15472035.66
# 1     USA  1883810.10       1930949.15           3637731.12
# 2     USA  2468079.29       4186694.69           7165111.24
#
#    Opening_Day_SalesUSD  One_Week_SalesUSD  IMDbRating  RottenTomatoesScore  \
# 0            1778530.85         3034053.32         6.2                   58
# 1             247115.74          831828.84         5.2                   44
# 2             878453.95         2171405.93         5.5                   55
#
#    NumVotesIMDb  NumVotesRT         Director        LeadActor
# ...

# %%
dataset.tail()
# Out:
#         MovieID                Title        Genre  ReleaseYear ReleaseDate  \
# 423109   423110  Anyone brother nice        Drama         2014  28-06-2014
# 423110   423111         Analysis day  Documentary         1992  28-06-1992
# 423111   423112         Bill surface       Action         1982  14-04-1982
# 423112   423113   Stand main measure       Comedy         1981  06-08-1981
# 423113   423114             Tough he       Action         2016  28-06-2016
#
#        Country    BudgetUSD  US_BoxOfficeUSD  Global_BoxOfficeUSD  \
# 423109     USA  10569896.91      29607489.20         5.023669e+07
# 423110     USA    463340.58        307446.66         7.570263e+05
# 423111     USA    441538.76        593843.92         9.215410e+05
# 423112     USA  27849455.06      75965044.47         1.250070e+08
# 423113     USA    372239.78        805528.53         1.358125e+06
#
#         Opening_Day_SalesUSD  One_Week_SalesUSD  IMDbRating  \
# ...

# %%
dataset.shape
# Out:
# (423114, 17)

# %%
dataset.dtypes
# Out:
# MovieID                   int64
# Title                    object
# Genre                    object
# ReleaseYear               int64
# ReleaseDate              object
# Country                  object
# BudgetUSD               float64
# US_BoxOfficeUSD         float64
# Global_BoxOfficeUSD     float64
# Opening_Day_SalesUSD    float64
# One_Week_SalesUSD       float64
# IMDbRating              float64
# RottenTomatoesScore       int64
# NumVotesIMDb              int64
# NumVotesRT                int64
# Director                 object
# LeadActor                object
# dtype: object

# %%
dataset.describe()
# Out:
#              MovieID    ReleaseYear     BudgetUSD  US_BoxOfficeUSD  \
# count  423114.000000  423114.000000  4.231140e+05     4.231140e+05
# mean   211557.500000    1998.028621  9.820786e+06     1.498183e+07
# std    122142.635236      19.267555  2.261979e+07     3.892631e+07
# min         1.000000    1950.000000  1.000000e+05     4.005388e+04
# 25%    105779.250000    1984.000000  1.193444e+06     1.488667e+06
# 50%    211557.500000    2001.000000  3.269029e+06     4.387757e+06
# 75%    317335.750000    2014.000000  8.996761e+06     1.282293e+07
# max    423114.000000    2025.000000  3.000000e+08     1.018198e+09
#
#        Global_BoxOfficeUSD  Opening_Day_SalesUSD  One_Week_SalesUSD  \
# count         4.231140e+05          4.231140e+05       4.231140e+05
# mean          2.725314e+07          2.993800e+06       7.495263e+06
# std           6.997506e+07          8.118235e+06       1.961680e+07
# min           1.000000e+05          4.238200e+03       1.650742e+04
# ...

# %%
dataset.isna().sum()
# Out:
# MovieID                 0
# Title                   0
# Genre                   0
# ReleaseYear             0
# ReleaseDate             0
# Country                 0
# BudgetUSD               0
# US_BoxOfficeUSD         0
# Global_BoxOfficeUSD     0
# Opening_Day_SalesUSD    0
# One_Week_SalesUSD       0
# IMDbRating              0
# RottenTomatoesScore     0
# NumVotesIMDb            0
# NumVotesRT              0
# Director                0
# LeadActor               1
# dtype: int64

# %%
dataset.isna().sum().sum()
# Out:
# np.int64(1)

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.columns
# Out:
# Index(['MovieID', 'Title', 'Genre', 'ReleaseYear', 'ReleaseDate', 'Country',
#        'BudgetUSD', 'US_BoxOfficeUSD', 'Global_BoxOfficeUSD',
#        'Opening_Day_SalesUSD', 'One_Week_SalesUSD', 'IMDbRating',
#        'RottenTomatoesScore', 'NumVotesIMDb', 'NumVotesRT', 'Director',
#        'LeadActor'],
#       dtype='object')

# %%
numeric_cols = ['BudgetUSD', 'US_BoxOfficeUSD','Global_BoxOfficeUSD','Opening_Day_SalesUSD','One_Week_SalesUSD','IMDbRating','RottenTomatoesScore','NumVotesIMDb']

# %%
for col in numeric_cols:
  sns.histplot(dataset[col], bins = 50, kde=True)
  plt.title(f'Distribution of {col}')
  plt.show()

# %%
dataset.columns
# Out:
# Index(['MovieID', 'Title', 'Genre', 'ReleaseYear', 'ReleaseDate', 'Country',
#        'BudgetUSD', 'US_BoxOfficeUSD', 'Global_BoxOfficeUSD',
#        'Opening_Day_SalesUSD', 'One_Week_SalesUSD', 'IMDbRating',
#        'RottenTomatoesScore', 'NumVotesIMDb', 'NumVotesRT', 'Director',
#        'LeadActor'],
#       dtype='object')

# %%
categorical_cols = ['Genre','Country','Director','LeadActor']

# %%
for col in categorical_cols:
  dataset[col].value_counts().head(20).plot(kind='bar')
  plt.title(f'Top 20 {col} count')
# Out:
# Genre
# Country
# Director
# LeadActor

# %%
dataset['Genre'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Genre'>

# %%
sns.scatterplot(data = dataset, x = 'BudgetUSD', y = 'Global_BoxOfficeUSD', alpha = 0.3)
plt.xscale('log')
plt.yscale('log')
