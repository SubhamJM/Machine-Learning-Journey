# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn
from xgboost import XGBRegressor

# %%
dataset = pd.read_csv('/content/HousingData.csv')

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
dataset.CRIM.fillna(dataset.CRIM.median(), inplace=True)
dataset.ZN.fillna(dataset.ZN.median(), inplace=True)
dataset.INDUS.fillna(dataset.INDUS.median(), inplace=True)
dataset.CHAS.fillna(dataset.CHAS.median(), inplace=True)
dataset.AGE.fillna(dataset.AGE.median(), inplace=True)
dataset.LSTAT.fillna(dataset.LSTAT.median(), inplace=True)
# Out:
# /tmp/ipython-input-915365480.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset.CRIM.fillna(dataset.CRIM.median(), inplace=True)
# /tmp/ipython-input-915365480.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
x = dataset.drop(['MEDV'], axis = 1)
y = dataset.MEDV
print(x)
print(y)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  76.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
correlation = dataset.corr()
correlation
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.185359  0.392632 -0.055585  0.410971 -0.220045  0.343427
# ZN      -0.185359  1.000000 -0.507304 -0.032992 -0.498619  0.312295 -0.535341
# INDUS    0.392632 -0.507304  1.000000  0.054693  0.738387 -0.377978  0.614248
# CHAS    -0.055585 -0.032992  0.054693  1.000000  0.070867  0.106797  0.074984
# NOX      0.410971 -0.498619  0.738387  0.070867  1.000000 -0.302188  0.711864
# RM      -0.220045  0.312295 -0.377978  0.106797 -0.302188  1.000000 -0.239518
# AGE      0.343427 -0.535341  0.614248  0.074984  0.711864 -0.239518  1.000000
# DIS     -0.366025  0.632428 -0.698621 -0.092318 -0.769230  0.205246 -0.724354
# RAD      0.601224 -0.300061  0.592735 -0.003339  0.611441 -0.209847  0.447088
# TAX      0.560469 -0.304385  0.716267 -0.035822  0.668023 -0.292048  0.498408
# PTRATIO  0.277964 -0.394622  0.385366 -0.109451  0.188933 -0.355501  0.261826
# ...

# %%
#constructing heatmap to understand the correlation
plt.figure(figsize=(10,10))
seaborn.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# <Axes: >

# %%
scalar = StandardScaler()

# %%
scalar.fit(x)
# Out:
# StandardScaler()

# %%
x = scalar.transform(x)

# %%
x
# Out:
# array([[-0.40559156,  0.31436884, -1.30170603, ..., -1.45900038,
#          0.44105193, -1.09619345],
#        [-0.40314013, -0.46815955, -0.59105154, ..., -0.30309415,
#          0.44105193, -0.50277932],
#        [-0.40314247, -0.46815955, -0.59105154, ..., -0.30309415,
#          0.39642699, -1.23170869],
#        ...,
#        [-0.3992335 , -0.46815955,  0.13453268, ...,  1.17646583,
#          0.44105193, -1.00204601],
#        [-0.39353063, -0.46815955,  0.13453268, ...,  1.17646583,
#          0.4032249 , -0.88222201],
#        [-0.40079265, -0.46815955,  0.13453268, ...,  1.17646583,
#          0.44105193, -0.68251533]])

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 43)

# %%
model = XGBRegressor()
model.fit(xtrain, ytrain)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xtestpredictions = model.predict(xtest)

# %%
r2_score(xtestpredictions, ytest)
# Out:
# 0.8554107156633348
